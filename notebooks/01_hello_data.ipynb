# %%
import sys
print("Version :", sys.version)
print("Exécutable :", sys.executable)
# Out:
# Version : 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Exécutable : c:\Users\safiy\OneDrive\Bureau\SAS_IA\ia_d1\.venv\Scripts\python.exe

# %%
data = [10, 20, 30, 40, 50]
for val in data:
    print(f"Traitement de : {val}")
# Out:
# Traitement de : 10
# Traitement de : 20
# Traitement de : 30
# Traitement de : 40
# Traitement de : 50

# %%
a = 10
b = 5
resultat = a * b
print(f"Le résultat de {a} x {b} est égal à {resultat}")
# Out:
# Le résultat de 10 x 5 est égal à 50

# %%
nombres = [2, 4, 6, 8, 10]
for n in nombres:
    print(f"Nombre au carré : {n**2}")
# Out:
# Nombre au carré : 4
# Nombre au carré : 16
# Nombre au carré : 36
# Nombre au carré : 64
# Nombre au carré : 100
